# %% [markdown]
# <a href="https://colab.research.google.com/github/lekshmisravi/datascience1/blob/main/TASK_2_DATA_SCIENCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lets Grow More**
#
# **Task 2**
#
# **Name : LEKSHMI S RAVI**
#
#
#
# **Data Science Internship**
#
#
#
# **Image to Pencil Sketch with Python**
#
# **Description Of Task :**We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %%
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# **Read the image**

# %%
image = cv2.imread("bird.jpg")
plt.figure(figsize=(8,8))
plt.imshow(image)
plt.show()

# %%
sb_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,8))
plt.imshow(sb_img)
plt.show()

# %% [markdown]
# **Converting the rgb image in to a gray scale image**

# %%
gray_img = cv2.cvtColor(sb_img, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(8,8))
plt.imshow(gray_img,cmap='gray')
plt.show()

# %% [markdown]
# **Converting the gray scale image in to a inverted image**

# %%
invertgrayimg =255 - gray_img
plt.figure(figsize=(8,8))
plt.imshow(invertgrayimg,cmap='gray')
plt.show()

# %% [markdown]
# **Bluring the inverted grayscale image using Gaussian Blur**

# %%
blurimg = cv2.GaussianBlur(invertgrayimg, (21,21), 0)
plt.figure(figsize=(8,8))
plt.imshow(blurimg,cmap='gray')
plt.show()

# %% [markdown]
# **Now inverting the blurred image**

# %%
invertblurimg = 255 - blurimg
plt.figure(figsize=(8,8))
plt.imshow(invertblurimg,cmap='gray')
plt.show()

# %% [markdown]
# **Now for the final touch divide the grayscale image with inverted blurred image**

# %%
sketch = cv2.divide(gray_img, invertblurimg, scale=256.0)
plt.figure(figsize=(8,8))
plt.imshow(sb_img)
plt.figure(figsize=(8,8))
plt.imshow(sketch,cmap='gray')
plt.show()
